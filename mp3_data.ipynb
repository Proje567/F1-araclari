# %% [markdown]
# # MP3 Veri İncelemesi
# Bu dosyada belge incelemesiyle oluşturulan veri seti okunur ve ilk satırlar gösterilir.

# %%
import pandas as pd

df = pd.read_csv('data_mp3_gelistirilmis.csv')
df.head()
